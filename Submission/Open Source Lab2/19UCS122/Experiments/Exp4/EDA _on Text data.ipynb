# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\VINOD\\Desktop\\amazon_baby.csv")
df.head(5)
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5

# %%
len(df)
# Out:
# 183531

# %%
df['name'].value_counts()
# Out:
# Vulli Sophie the Giraffe Teether                                                                                  785
# Simple Wishes Hands-Free Breastpump Bra, Pink, XS-L                                                               562
# Infant Optics DXR-5 2.4 GHz Digital Video Baby Monitor with Night Vision                                          561
# Baby Einstein Take Along Tunes                                                                                    547
# Cloud b Twilight Constellation Night Light, Turtle                                                                520
# Fisher-Price Booster Seat, Blue/Green/Gray                                                                        489
# Fisher-Price Rainforest Jumperoo                                                                                  450
# Graco Nautilus 3-in-1 Car Seat, Matrix                                                                            419
# Leachco Snoogle Total Body Pillow                                                                                 388
# Regalo Easy Step Walk Thru Gate, White                                                                            374
# Baby Trend Diaper Champ                                                                                           333
# Skip Hop Zoo Pack Little Kid Backpack, Dog                                                                        286
# NTM-910YIC - Sony Baby Call Nursery Monitor                                                                       284
# The First Years Jet Stroller, Red/Black                                                                           284
# Leachco Back \'N Belly Contoured Body Pillow, Ivory                                                               283
# North States Superyard Play Yard, Grey, 6 Panel                                                                   281
# Fisher-Price Cradle \'N Swing,  My Little Snugabunny                                                              278
# Munchkin Nursery Projector and Sound System, White                                                                242
# Tiny Love Take-Along Arch, Sunny Stroll                                                                           241
# Regalo Easy Open 50 Inch Super Wide Walk Thru Gate - White                                                        238
# Fisher-Price Newborn Rock \'n Play Sleeper, Yellow                                                                236
# VTech Communications Safe &amp; Sound Digital Audio Monitor                                                       233
# Fisher-Price Rainforest Melodies and Lights Deluxe Gym                                                            232
# BABYBJORN Potty Chair - Red                                                                                       232
# The First Year\'s Infant To Toddler Tub with Sling, Blue                                                          230
# Thermos Foogo Leak-Proof Stainless Steel 10-Ounce Food Jar, Pink                                                  226
# Summer Infant Multi-Use Deco Extra Tall Walk-Thru Gate, Bronze                                                    219
# The First Years Ignite Stroller                                                                                   218
# Fisher-Price Infant-To-Toddler Rocker, Blue/Green                                                                 217
# Prince Lionheart Jumbo Toy Hammock                                                                                217
#                                                                                                                  ...
# Trend Lab Striped and Dot Two Picture Frame Set in Brown/Pink                                                       1
# Bearington Baby Wiggles Pacifier Clip                                                                               1
# Evenflo XSport Folding Umbrella Stroller- Pink                                                                      1
# Cotton Tale Designs Tiger Tale Musical Mobile                                                                       1
# Neat Solutions Attitude Sayings Bib Set, Boy, 4-Count                                                               1
# SwaddleMe Mobile - Lady Bug Garden                                                                                  1
# Summer Infant Tiny Diner, Minnie                                                                                    1
# Sofantex Cute Baby Play Rug / Mat (Bottom: Pink - Top: Green)                                                       1
# WubbaNub Infant Plush Toy Pacifier - Blue Bear                                                                      1
# SheetWorld Baseball Bear Fabric - By The Yard                                                                       1
# Kanga Kid Sunroof with Rain Shield                                                                                  1
# Disney Jr Junction Fast Friends 30&quot;x40&quot; Rug                                                               1
# BabyKicks 6 Count Stay Dry Diaper Liner, White                                                                      1
# Stock Car Wall Stickers/Decals/ Graphics                                                                            1
# Shapewear Lycra - Nylon Body Braless Strapless Panty Type corset Waist Cin...                                       1
# Tadpoles Playmat Set, Teddy and Friends Brown                                                                       1
# OsoCozy Prefold Cloth Diaper Basic Package - Unbleached Prefolds &amp; Froggy Print Bummis Super Whisper Wraps      1
# Carter\'s Baby\'s First Prints Kit, Menagerie                                                                       1
# Ecru Chenille Changing Pad Cover                                                                                    1
# CoCaLo Mix &amp; Match Pleated Dust Ruffle, Connor                                                                  1
# Blankets and Beyond Lovely Decorated Elephant Patchwork Blanket Pink                                                1
# CoCo &amp; Company Musical Mobile, Monkey Time                                                                      1
# GoBaby Teddytoes Classic Navy Sz 2 (6-18 Mo)                                                                        1
# Kissa\'s Diaper Print Cover, Starburst                                                                              1
# 6 pair Gerber Training Pants 2T Girl 28-32 pounds                                                                   1
# Sumersault Moo Cow Rug                                                                                              1
# Arm\'s Reach Concepts Mini Arc Co-Sleeper Bedside Bassinet, Toffee Dot                                              1
# The First Years 2 Pack GumDrop Replacement Nipples, Colors May Vary                                                 1
# The First Years 2 Pack Mickey Mouse Infant Pacifier                                                                 1
# Bright Starts Cruise N\' Sort Bus Toy                                                                               1
# Name: name, Length: 32417, dtype: int64

# %%
df=df[df.groupby('name')["name"].transform('size')>20]

# %%
df
# Out:
#                                                      name  \
# 153                  Fisher Price Nesting Action Vehicles
# 154                  Fisher Price Nesting Action Vehicles
# 155                  Fisher Price Nesting Action Vehicles
# 156                  Fisher Price Nesting Action Vehicles
# 157                  Fisher Price Nesting Action Vehicles
# 158                  Fisher Price Nesting Action Vehicles
# 159                  Fisher Price Nesting Action Vehicles
# 160                  Fisher Price Nesting Action Vehicles
# 161                  Fisher Price Nesting Action Vehicles
# 162                  Fisher Price Nesting Action Vehicles
# 163                  Fisher Price Nesting Action Vehicles
# 164                  Fisher Price Nesting Action Vehicles
# 165                  Fisher Price Nesting Action Vehicles
# 166                  Fisher Price Nesting Action Vehicles
# 167                  Fisher Price Nesting Action Vehicles
# 168                  Fisher Price Nesting Action Vehicles
# 169                  Fisher Price Nesting Action Vehicles
# 170                  Fisher Price Nesting Action Vehicles
# 171                  Fisher Price Nesting Action Vehicles
# 172                  Fisher Price Nesting Action Vehicles
# 173                  Fisher Price Nesting Action Vehicles
# 174                  Fisher Price Nesting Action Vehicles
# 175                  Fisher Price Nesting Action Vehicles
# 176                  Fisher Price Nesting Action Vehicles
# 177                  Fisher Price Nesting Action Vehicles
# 234              The First Years Massaging Action Teether
# 235              The First Years Massaging Action Teether
# 236              The First Years Massaging Action Teether
# 237              The First Years Massaging Action Teether
# 238              The First Years Massaging Action Teether
# ...                                                   ...
# 183453  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183454  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183455  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183456  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183457  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183458  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183492  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183493  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183494  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183495  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183496  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183497  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183498  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183499  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183500  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183501  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183502  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183503  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183504  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183505  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183506  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183507  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183508  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183509  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183510  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183511  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183512  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183513  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183514  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183515  Maxboost iPhone 5S/5 Case - Protective Snap-on...
#
#                                                    review  rating
# 153     We bought these for our son when he turned two...       5
# 154     My son loves stacking cups, so a friend recomm...       5
# 155     My son Cameron just loves these great little s...       5
# 156     My one year old son received these as a birthd...       5
# 157     I purchased this toy for my great grandson\'s ...       5
# 158     I\'ve owned this set for several years.  My 4 ...       4
# 159     These are a huge hit with my one year old son....       5
# 160     This is a great toy.  The wheels really work a...       5
# 161     My 11 month old received these last Christmas ...       5
# 162     My 14 month old son loves to stack and play wi...       5
# 163     Great toys, we always pack one or two in the d...       5
# 164     My son has played with these from 6 months old...       4
# 165     After being inundated with toys that require b...       5
# 166     I bought these for my 1 1/2 year old, and he l...       4
# 167     We bought these trucks for our 15 mo. old daug...       5
# 168     My son got this stacking truck set as a baby g...       5
# 169     I bought the cars because they were easy to st...       4
# 170     My daughter loves these vehicles. She likes to...       5
# 171     My son loves this stacking toy. It is much mor...       5
# 172     I got this toy for my daughter when she was ve...       4
# 173     Okay, well they don\'t really beep.  (But my 1...       5
# 174     For well over a year my son has enjoyed stacki...       5
# 175     We just bought this for my 9 month old daughte...       5
# 176     My son got this for Christmas and he loves all...       4
# 177     This is a wonderful toy that is fun, education...       5
# 234     all three of my kids have had one of these tee...       5
# 235     I\'ve tried this for almost 6 months at differ...       2
# 236     This teether is ridiculous. It\'s huge, it\'s ...       1
# 237     One of my friends recommended this for me for ...       5
# 238     Great teether as it has a good texture, is eas...       5
# ...                                                   ...     ...
# 183453  I received a free sample from VIPU program for...       5
# 183454  I received a free sample from VIPU program for...       5
# 183455  I really liked this case I think that it is ve...       4
# 183456  Great case and very sturdy! The different colo...       5
# 183457  I received a free sample from VIPU program for...       5
# 183458  I received a free sample from VIPU program for...       5
# 183492  This i got for one of my friends becuase she w...       5
# 183493  I love maxboost best phone company ever, I was...       5
# 183494  I got this case as a free sample and it is gre...       5
# 183495  Love how this case looks on my phone simple an...       5
# 183496  Love this case. It is very thin,looks and feel...       5
# 183497  I love the color , And is everything I expecte...       5
# 183498  After receiving my free case from a giveaway, ...       5
# 183499  I received a free sample from VIPU program for...       5
# 183500  Great product, great company! Their daily give...       5
# 183501  I received a free sample from VIPU program for...       5
# 183502  It got here incredibly fast & it is a nice dur...       5
# 183503  I got this case in the mail today, it came on ...       2
# 183504  Free caseLove it... The color was great firm h...       5
# 183505  I received a free sample from VIPU program for...       5
# 183506  This case definitely isn\'t cheap. It feels ve...       5
# 183507  got this for my wife and she loves it would de...       5
# 183508  love this case. It fit perfectly and the color...       5
# 183509  this case is the greatest very cool and stylis...       5
# 183510              Great fit. Really love how red it is.       5
# 183511  I received a free sample from VIPU program for...       3
# 183512  *I received a free sample from VIPU program fo...       5
# 183513  I was a very surprised by the quality of this ...       5
# 183514  I received a free sample from VIPU program for...       4
# 183515  I love this phone case!  My  iPhone is always ...       5
#
# [89691 rows x 3 columns]

# %%
df=df.head(10000)
df
# Out:
#                                                     name  \
# 153                 Fisher Price Nesting Action Vehicles
# 154                 Fisher Price Nesting Action Vehicles
# 155                 Fisher Price Nesting Action Vehicles
# 156                 Fisher Price Nesting Action Vehicles
# 157                 Fisher Price Nesting Action Vehicles
# 158                 Fisher Price Nesting Action Vehicles
# 159                 Fisher Price Nesting Action Vehicles
# 160                 Fisher Price Nesting Action Vehicles
# 161                 Fisher Price Nesting Action Vehicles
# 162                 Fisher Price Nesting Action Vehicles
# 163                 Fisher Price Nesting Action Vehicles
# 164                 Fisher Price Nesting Action Vehicles
# 165                 Fisher Price Nesting Action Vehicles
# 166                 Fisher Price Nesting Action Vehicles
# 167                 Fisher Price Nesting Action Vehicles
# 168                 Fisher Price Nesting Action Vehicles
# 169                 Fisher Price Nesting Action Vehicles
# 170                 Fisher Price Nesting Action Vehicles
# 171                 Fisher Price Nesting Action Vehicles
# 172                 Fisher Price Nesting Action Vehicles
# 173                 Fisher Price Nesting Action Vehicles
# 174                 Fisher Price Nesting Action Vehicles
# 175                 Fisher Price Nesting Action Vehicles
# 176                 Fisher Price Nesting Action Vehicles
# 177                 Fisher Price Nesting Action Vehicles
# 234             The First Years Massaging Action Teether
# 235             The First Years Massaging Action Teether
# 236             The First Years Massaging Action Teether
# 237             The First Years Massaging Action Teether
# 238             The First Years Massaging Action Teether
# ...                                                  ...
# 14277  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14278  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14279  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14280  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14281  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14282  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14283  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14284  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14285  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14286  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14287  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14288  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14289  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14290  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14291  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14292  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14293  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14294  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14295  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14296  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14297  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14298  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14299  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14300  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14301  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14302  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14303  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14304  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14305  Leachco Back \'N Belly Contoured Body Pillow, ...
# 14306  Leachco Back \'N Belly Contoured Body Pillow, ...
#
#                                                   review  rating
# 153    We bought these for our son when he turned two...       5
# 154    My son loves stacking cups, so a friend recomm...       5
# 155    My son Cameron just loves these great little s...       5
# 156    My one year old son received these as a birthd...       5
# 157    I purchased this toy for my great grandson\'s ...       5
# 158    I\'ve owned this set for several years.  My 4 ...       4
# 159    These are a huge hit with my one year old son....       5
# 160    This is a great toy.  The wheels really work a...       5
# 161    My 11 month old received these last Christmas ...       5
# 162    My 14 month old son loves to stack and play wi...       5
# 163    Great toys, we always pack one or two in the d...       5
# 164    My son has played with these from 6 months old...       4
# 165    After being inundated with toys that require b...       5
# 166    I bought these for my 1 1/2 year old, and he l...       4
# 167    We bought these trucks for our 15 mo. old daug...       5
# 168    My son got this stacking truck set as a baby g...       5
# 169    I bought the cars because they were easy to st...       4
# 170    My daughter loves these vehicles. She likes to...       5
# 171    My son loves this stacking toy. It is much mor...       5
# 172    I got this toy for my daughter when she was ve...       4
# 173    Okay, well they don\'t really beep.  (But my 1...       5
# 174    For well over a year my son has enjoyed stacki...       5
# 175    We just bought this for my 9 month old daughte...       5
# 176    My son got this for Christmas and he loves all...       4
# 177    This is a wonderful toy that is fun, education...       5
# 234    all three of my kids have had one of these tee...       5
# 235    I\'ve tried this for almost 6 months at differ...       2
# 236    This teether is ridiculous. It\'s huge, it\'s ...       1
# 237    One of my friends recommended this for me for ...       5
# 238    Great teether as it has a good texture, is eas...       5
# ...                                                  ...     ...
# 14277  I was nervous about buying such a big pillow, ...       5
# 14278  I can not say enough good things about this pi...       5
# 14279  Got me through the second half of pregnancy wi...       5
# 14280  I feel like I\'m sleeping in a plush little ne...       4
# 14281  It helps relieve pressure off my back when I u...       4
# 14282  I was starting to wake up from bad back pain i...       5
# 14283  There is lots to love about this pillow. The s...       2
# 14284  perfect body pillow for my pregnant wife! it w...       5
# 14285  Like others have mentioned, the seam around th...       3
# 14286  I bought this for my daughter who had been hav...       5
# 14287  My wife loved this! She was having some back p...       5
# 14288  Thankfully I have a king size bed because this...       4
# 14289  This is such a comfortable pillow! Definitely ...       5
# 14290  This pillow was wonderful when I got it, I rea...       3
# 14291  Extremely comfortable and reliable.  Lasts for...       5
# 14292  I absolutely love this pillow. It supports you...       5
# 14293  My wife was uncomfortable sleeping before the ...       5
# 14294  This pillow worked so great and was very comfo...       5
# 14295  We purchased the pillow when I was in my fourt...       5
# 14296  My wifed loves using this. She said its helps ...       5
# 14297  Amazing product.  My wife thought it was a lif...       5
# 14298  I like this pillow, it provides support in all...       3
# 14299  First, let me say that I\'m a guy and obviousl...       5
# 14300  The price was the first thing that had me sold...       4
# 14301  I\'m currently 6 months along in my pregnancy ...       4
# 14302  So comfortable, and great for several sleeping...       5
# 14303  This pillow has been one of the best pregnancy...       5
# 14304  This is one of those things that is as good as...       5
# 14305  I love this pillow!  I love being able to roll...       5
# 14306  This pillow is so comfy and I am sleeping much...       5
#
# [10000 rows x 3 columns]

# %%
df['review']=df['review'].astype(str)
# Out:
# C:\Users\VINOD\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
len(df)
# Out:
# 10000

# %%
 def clean(txt):
    txt = txt.str.replace("()", "")
    txt = txt.str.replace('(<a).*(>).*()', '')
    txt = txt.str.replace('(&amp)', '')
    txt = txt.str.replace('(&gt)', '')
    txt = txt.str.replace('(&lt)', '')
    txt = txt.str.replace('(\xa0)', ' ')  
    txtdf['review'] = clean(df['review'])
    return txtdf['review']

# %%
df.head(5)
# Out:
#                                      name  \
# 153  Fisher Price Nesting Action Vehicles
# 154  Fisher Price Nesting Action Vehicles
# 155  Fisher Price Nesting Action Vehicles
# 156  Fisher Price Nesting Action Vehicles
# 157  Fisher Price Nesting Action Vehicles
#
#                                                 review  rating
# 153  We bought these for our son when he turned two...       5
# 154  My son loves stacking cups, so a friend recomm...       5
# 155  My son Cameron just loves these great little s...       5
# 156  My one year old son received these as a birthd...       5
# 157  I purchased this toy for my great grandson\'s ...       5

# %%
df['review1'] = df['review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
# Out:
# C:\Users\VINOD\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['review1'].head(5)
# Out:
# 153    we bought these for our son when he turned two...
# 154    my son loves stacking cups, so a friend recomm...
# 155    my son cameron just loves these great little s...
# 156    my one year old son received these as a birthd...
# 157    i purchased this toy for my great grandson\'s ...
# Name: review1, dtype: object

# %%
df['review1'] = df['review1'].str.replace('[^\w\s]', '')
df['review1'].head()
# Out:
# C:\Users\VINOD\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 153    we bought these for our son when he turned two...
# 154    my son loves stacking cups so a friend recomme...
# 155    my son cameron just loves these great little s...
# 156    my one year old son received these as a birthd...
# 157    i purchased this toy for my great grandsons fi...
# Name: review1, dtype: object

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords 
stop = stopwords.words('english')
df['review1'] = df['review1'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df['review1'].head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VINOD\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\VINOD\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# 153    bought son turned two seen playmates home love...
# 154    son loves stacking cups friend recommended toy...
# 155    son cameron loves great little stacking cars e...
# 156    one year old son received birthday gift loves ...
# 157    purchased toy great grandsons first christmas ...
# Name: review1, dtype: object

# %%
df['review1'].head(5)
# Out:
# 153    bought son turned two seen playmates home love...
# 154    son loves stacking cups friend recommended toy...
# 155    son cameron loves great little stacking cars e...
# 156    one year old son received birthday gift loves ...
# 157    purchased toy great grandsons first christmas ...
# Name: review1, dtype: object

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['review1'] = df['review'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# C:\Users\VINOD\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df['review1'].head(5)
# Out:
# 153    We bought these for our son when he turn two. ...
# 154    My son love stack cups, so a friend recommend ...
# 155    My son cameron just love these great littl sta...
# 156    My one year old son receiv these as a birthday...
# 157    I purchas thi toy for my great grandson\' firs...
# Name: review1, dtype: object
