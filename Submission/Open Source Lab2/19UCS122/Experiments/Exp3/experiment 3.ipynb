# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("C:\\Users\\Student\\Desktop\\19ucs026\\Dataset\\3. Descriptive Statistics.xlsx")
df
# Out:
#       ID Gender           Birth Date  Education  JobCategory  CurrentSalary  \
# 0      3      f           07/26/1929         12            1          21450
# 1      4      f           04/15/1947          8            1          21900
# 2      8      f  1966-06-05 00:00:00         12            1          21900
# 3      9      f           01/23/1946         15            1          27900
# 4     10      f           02/13/1946         12            1          24000
# ..   ...    ...                  ...        ...          ...            ...
# 469  464      m           03/20/1962         19            3          47550
# 470  465      m           07/20/1962         12            1          33900
# 471  470      m           01/22/1964         12            1          26250
# 472  471      m  1966-03-08 00:00:00         15            1          26400
# 473  472      m           02/21/1966         15            1          39150
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Gender', 'Birth Date', 'Education', 'JobCategory',
#        'CurrentSalary', 'After6Months', 'SalBegin', 'Job Time', 'Prev Exep',
#        'Minority', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %%
df[['CurrentSalary','After6Months','SalBegin']].mean()
# Out:
# CurrentSalary    34419.567511
# After6Months     25717.827004
# SalBegin         17016.086498
# dtype: float64

# %%
df[['CurrentSalary','After6Months','SalBegin']].medianan()
# Out:
# CurrentSalary    28875.0
# After6Months     21900.0
# SalBegin         15000.0
# dtype: float64

# %%
df[['Job Time']].mode()
# Out:
#    Job Time
# 0        81
# 1        93

# %%
df.describe()
# Out:
#                ID   Education  JobCategory  CurrentSalary   After6Months  \
# count  474.000000  474.000000   474.000000     474.000000     474.000000
# mean   237.500000   13.491561     1.411392   34419.567511   25717.827004
# std    136.976275    2.884846     0.773201   17075.661465   12145.928474
# min      1.000000    8.000000     1.000000   15750.000000   12975.000000
# 25%    119.250000   12.000000     1.000000   24000.000000   18468.750000
# 50%    237.500000   12.000000     1.000000   28875.000000   21900.000000
# 75%    355.750000   15.000000     1.000000   36937.500000   27262.500000
# max    474.000000   21.000000     3.000000  135000.000000  107490.000000
#
#            SalBegin    Job Time   Prev Exep    Minority  Unnamed: 11  \
# count    474.000000  474.000000  474.000000  474.000000          0.0
# mean   17016.086498   81.109705   95.860759    0.219409          NaN
# std     7870.638154   10.060945  104.586236    0.414284          NaN
# ...

# %%
plt.figure(figsize=[7,5])
plt.hist(df.CurrentSalary)
# Out:
# (array([210., 158.,  39.,  28.,  22.,   8.,   4.,   4.,   0.,   1.]),
#  array([ 15750.,  27675.,  39600.,  51525.,  63450.,  75375.,  87300.,
#          99225., 111150., 123075., 135000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df.CurrentSalary,df.SalBegin)
plt.xlabel("Current Salary")
plt.ylabel("Begin Salary")
# Out:
# Text(0, 0.5, 'Begin Salary')

# %% [markdown]
# #  2. Group By

# %%
df2 = pd.read_csv("city_weather.csv")
df2
# Out:
#            day      city  temperature  windspeed   event  Unnamed: 5
# 0   01/01/2017  new york           32          6    Rain         NaN
# 1   01/02/2017  new york           36          7   Sunny         NaN
# 2   01/03/2017  new york           28         12    Snow         NaN
# 3   01/04/2017  new york           33          7   Sunny         NaN
# 4   01/01/2017    mumbai           90          5   Sunny         NaN
# 5   01/02/2017    mumbai           85         12     Fog         NaN
# 6   01/03/2017    mumbai           87         15     Fog         NaN
# 7   01/04/2017    mumbai           92          5    Rain         NaN
# 8   01/01/2017     paris           45         20   Sunny         NaN
# 9   01/02/2017     paris           50         13  Cloudy         NaN
# 10  01/03/2017     paris           54          8  Cloudy         NaN
# 11  01/04/2017     paris           42         10  Cloudy         NaN

# %%
gb_city = df2.groupby('city') 
gb_city

# %%
for city,city_df in gb_city:
    print(city)
    print(city_df)
# Out:
# mumbai
#           day    city  temperature  windspeed  event  Unnamed: 5
# 4  01/01/2017  mumbai           90          5  Sunny         NaN
# 5  01/02/2017  mumbai           85         12    Fog         NaN
# 6  01/03/2017  mumbai           87         15    Fog         NaN
# 7  01/04/2017  mumbai           92          5   Rain         NaN
# new york
#           day      city  temperature  windspeed  event  Unnamed: 5
# 0  01/01/2017  new york           32          6   Rain         NaN
# 1  01/02/2017  new york           36          7  Sunny         NaN
# 2  01/03/2017  new york           28         12   Snow         NaN
# 3  01/04/2017  new york           33          7  Sunny         NaN
# paris
#            day   city  temperature  windspeed   event  Unnamed: 5
# 8   01/01/2017  paris           45         20   Sunny         NaN
# 9   01/02/2017  paris           50         13  Cloudy         NaN
# 10  01/03/2017  paris           54          8  Cloudy         NaN
# ...

# %%
gb_city.get_group('mumbai')
# Out:
#           day    city  temperature  windspeed  event  Unnamed: 5
# 4  01/01/2017  mumbai           90          5  Sunny         NaN
# 5  01/02/2017  mumbai           85         12    Fog         NaN
# 6  01/03/2017  mumbai           87         15    Fog         NaN
# 7  01/04/2017  mumbai           92          5   Rain         NaN

# %%
gb_city.get_group('paris')
# Out:
#            day   city  temperature  windspeed   event  Unnamed: 5
# 8   01/01/2017  paris           45         20   Sunny         NaN
# 9   01/02/2017  paris           50         13  Cloudy         NaN
# 10  01/03/2017  paris           54          8  Cloudy         NaN
# 11  01/04/2017  paris           42         10  Cloudy         NaN

# %%
gb_city.max()
# Out:
#                  day  temperature  windspeed  event  Unnamed: 5
# city
# mumbai    01/04/2017           92         15  Sunny         NaN
# new york  01/04/2017           36         12  Sunny         NaN
# paris     01/04/2017           54         20  Sunny         NaN

# %%
gb_city.get_group('mumbai').max()
# Out:
# day            01/04/2017
# city               mumbai
# temperature            92
# windspeed              15
# event               Sunny
# Unnamed: 5            NaN
# dtype: object

# %%
gb_city.min()
# Out:
#                  day  temperature  windspeed   event  Unnamed: 5
# city
# mumbai    01/01/2017           85          5     Fog         NaN
# new york  01/01/2017           28          6    Rain         NaN
# paris     01/01/2017           42          8  Cloudy         NaN

# %%
gb_city.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed         ...              Unnamed: 5                       \
#              count   mean  ...    75%   max      count mean std min 25% 50%
# city                       ...
# mumbai         4.0   9.25  ...  12.75  15.0        0.0  NaN NaN NaN NaN NaN
# new york       4.0   8.00  ...   8.25  12.0        0.0  NaN NaN NaN NaN NaN
# paris          4.0  12.75  ...  14.75  20.0        0.0  NaN NaN NaN NaN NaN
#
#
#          75% max
# city
# mumbai   NaN NaN
# new york NaN NaN
# paris    NaN NaN
#
# [3 rows x 24 columns]

# %%
gb_city.plot()
plt.legend()
#plt.title('Mumbai')

# %%
gb_city.get_group('mumbai').plot(title='Mumbai',xlabel='Wind Speed', ylabel='Temperature')
gb_city.get_group('new york').plot(title='New York',xlabel='Wind Speed', ylabel='Temperature')
gb_city.get_group('paris').plot(title='Paris', xlabel='Wind Speed', ylabel='Temperature')
# Out:
# <AxesSubplot:title={'center':'Paris'}, xlabel='Wind Speed', ylabel='Temperature'>

# %%
from scipy import stats

# %%
df3 = pd.read_excel('Anova_Dataset.xlsx')
df3
# Out:
#     RunID  Power   GrowthRate
# 0       1      8  5002.320019
# 1       2      8  5003.601457
# 2       3      8  5001.024675
# 3       4      8  5001.576370
# 4       1     10  5070.505941
# 5       2     10  5056.109720
# 6       3     10  5069.544395
# 7       4     10  5082.979071
# 8       1     12  5096.413747
# 9       2     12  5109.848422
# 10      3     12  5123.283098
# 11      4     12  5136.717774
# 12      1     14  5150.152449
# 13      2     14  5163.587125
# 14      3     14  5177.021801
# 15      4     14  5190.456476
# 16      1     16  5203.891152
# 17      2     16  5217.325828
# 18      3     16  5230.760504
# 19      4     16  5244.195179

# %%
sns.boxplot(x='Power', y='GrowthRate', data=df3)
# Out:
# <AxesSubplot:xlabel='Power', ylabel='GrowthRate'>

# %% [markdown]
# Change the Persepective of data

# %%
df3_pivot = df3.pivot(index='RunID', columns='Power', values='GrowthRate')
df3_pivot
# Out:
# Power           8            10           12           14           16
# RunID
# 1      5002.320019  5070.505941  5096.413747  5150.152449  5203.891152
# 2      5003.601457  5056.109720  5109.848422  5163.587125  5217.325828
# 3      5001.024675  5069.544395  5123.283098  5177.021801  5230.760504
# 4      5001.576370  5082.979071  5136.717774  5190.456476  5244.195179

# %%
df3_pivot.sum()
# Out:
# Power
# 8     20008.522521
# 10    20279.139127
# 12    20466.263041
# 14    20681.217852
# 16    20896.172663
# dtype: float64

# %%
def degrees_of_freedom(df3_pivot):
    ## Between samples is across the row
    ## Within samples is down the column
    n = df3_pivot.count(axis=1) # Define number of replicates within treatment
    a = df3_pivot.count() # Determine number of treatments
    n = n.iloc[0]
    a = a.iloc[0]
    
    TotalN = n*a # Total number of samples
    dft = a - 1 #dft is degrees of freedom between sample set
    dfe = TotalN - a #dfe is degrees of freedom within samples
    dftotal = TotalN-1 #dftotal is degrees of freedom total 
    return dft, dfe, dftotal,n, a

# %%
dft, dfe, dftotal,n,a = degrees_of_freedom(df3_pivot)

print("Degrees of freedom between treatments: {:d}".format(dft))
print("Degrees of freedom within treatments: {:d}".format(dfe))
print("Total degrees of freedom: {:d}".format(dftotal))
# Out:
# Degrees of freedom between treatments: 3
# Degrees of freedom within treatments: 16
# Total degrees of freedom: 19

# %%
def compute_sums(df3_pivot):
    yi_sum = df3_pivot.sum() # Compute sum under i-th treatment
    yi_avg = df3_pivot.mean() # Compute average under i-th treatment 
    y_sum = yi_sum.sum() # Compute grand sum
    y_avg = yi_avg.mean() # Compute grand average
    return yi_sum, yi_avg, y_sum, y_avg

yi_sum, yi_avg, y_sum, y_avg = compute_sums(df3_pivot) #retrieve respective sums by calling function

print(r"The sum under each Power (W) treatment is: {}".format(yi_sum))
print(r"The average under each Power (W) treatment is: {}".format(yi_avg))
print(r"The grand sum is: {:.2f}".format(y_sum))
print(r"The grand average is: {:.2f}".format(y_avg))
# Out:
# The sum under each Power (W) treatment is: Power
# 8     20008.522521
# 10    20279.139127
# 12    20466.263041
# 14    20681.217852
# 16    20896.172663
# dtype: float64
# The average under each Power (W) treatment is: Power
# 8     5002.130630
# 10    5069.784782
# 12    5116.565760
# 14    5170.304463
# 16    5224.043166
# dtype: float64
# The grand sum is: 102331.32
# The grand average is: 5116.57

# %%
def Sum_of_Squares(yi_avg, y_avg, df3_pivot):
    SSTR = (yi_avg - y_avg)**2 #Calculate sum of squares between treatments
    SSTR = SSTR.sum()*n
    SSE = df3_pivot.sub(yi_avg.values) ** 2 #Calculate sum of squares within treatments
    SSE = SSE.sum().sum()
    SST = SSTR + SSE # Total corrected sum of squares
    return SSTR, SSE, SST

SSTR, SSE, SST = Sum_of_Squares(yi_avg,y_avg, df3_pivot)

print("Sum of Squares between treatments is: {:.2f}".format(SSTR))
print("Sum of Squares within treatments is: {:.2f}".format(SSE))
print("Total Sum of Squares is: {:.2f}".format(SST))
# Out:
# Sum of Squares between treatments is: 148615.50
# Sum of Squares within treatments is: 3072.76
# Total Sum of Squares is: 151688.26

# %%
from scipy import stats

# %% [markdown]
# Correlation: a measure of the extent of interdependence between variables.
#
# Causation: the relationship between cause and effect between two variables.

# %% [markdown]
# Pearson Correlation
#
#     The Pearson Correlation measures the linear dependence between two variables X and Y.
#
#     The resulting coefficient is a value between -1 and 1 inclusive, where:
#
#     1: Total positive linear correlation.
#     0: No linear correlation, the two variables most likely do not affect each other.
#     -1: Total negative linear correlation.

# %%
data = pd.read_csv("automobileEDA.csv")
data
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
data.corr() #Default method to find the correlation....
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# p-values are used in correlation to show the significant between two variables..P-value is nothing but the probability of null hypothesis to be true.As less as p-value(like p-value < 0.00), so there is correlation is more significant. And also as the more value of correlation ,they  are strongly depend on each other

# %%
person_coef, p_value = stats.pearsonr(data['wheel-base'],data['price'])
print('Pearson Correlation coefficicent is : ',person_coef,'with the p-value : ',p_value)
# Out:
# Pearson Correlation coefficicent is :  0.5846418222655081 with the p-value :  8.076488270732989e-20

# %% [markdown]
# There isn't extremely strong linear relationship between wheel-base and price

# %%
pearson_coef, p_value = stats.pearsonr(data['horsepower'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.809574567003656  with a P-value of P =  6.369057428259557e-48

# %% [markdown]
# As value of p < 0.001 and correlation is 0.80 So There is quite strong linear relationship between wheel-base and price

# %%
pearson_coef, p_value = stats.pearsonr(data['length'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.690628380448364  with a P-value of P =  8.016477466158986e-30

# %% [markdown]
# Since the p-value is  <  0.001, the correlation between length and price is statistically significant, and the linear relationship is moderately strong (~0.691).

# %%
earson_coef, p_value = stats.pearsonr(data['city-mpg'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.690628380448364  with a P-value of P =  2.321132065567674e-29

# %% [markdown]
# Since the p-value is  <  0.001, the correlation between city-mpg and price is statistically significant, and the coefficient of ~ -0.687 shows that the relationship is negative and moderately strong.

# %%
pearson_coef, p_value = stats.pearsonr(data['bore'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =  ", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626602  with a P-value of P =   8.049189483935489e-17

# %% [markdown]
# Since the p-value is  <  0.001, the correlation between bore and price is statistically significant, but the linear relationship is only moderate (~0.521).

# %%
pearson_coef, p_value = stats.pearsonr(data['engine-size'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185  with a P-value of P = 9.265491622198389e-64

# %% [markdown]
# Since the p-value is  <  0.001, the correlation between engine-size and price is statistically significant, and the linear relationship is very strong (~0.872).

# %%
sns.boxplot(x="engine-size", y="price", data=data)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
data= data.fillna(method="ffill")   #AS there are some values in column of 'stroke' are null so to replace it with corresponding forward values..
data #Pearson's method fails due to nan values. So I replaced that null values
# Out:
#      symboling  normalized-losses         make aspiration num-of-doors  \
# 0            3                122  alfa-romero        std          two
# 1            3                122  alfa-romero        std          two
# 2            1                122  alfa-romero        std          two
# 3            2                164         audi        std         four
# 4            2                164         audi        std         four
# ..         ...                ...          ...        ...          ...
# 196         -1                 95        volvo        std         four
# 197         -1                 95        volvo      turbo         four
# 198         -1                 95        volvo        std         four
# 199         -1                 95        volvo      turbo         four
# 200         -1                 95        volvo      turbo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
pearson_coef, p_value = stats.pearsonr(data['stroke'], data['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.08233412044691205  with a P-value of P = 0.245242991530309

# %%
sns.boxplot(x="stroke", y="price", data=data)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %% [markdown]
# p-value is very large(p>0.1) so there is no significant correlation is present and peterson's correlation coefficient is very low hence linear relationship isn't strong

# %% [markdown]
# pear, p_value = stats.pearsonr(data['make'],data['price'])
# print("The Pearson Correlation Coefficient is", pear, " with a P-value of P =", p_value)

# %% [markdown]
# #Pearson's Correlation won't work with categorical data

# %% [markdown]
# # 5.ANOVA (F-Test)

# %% [markdown]
# The Analysis of Variance (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:
#
# F-test score: ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#
# P-value: P-value tells how statistically significant is our calculated score value.
#
# If our price variable is strongly correlated with the variable we are analyzing, expect ANOVA to return a sizeable F-test score and a small p-value.

# %%
df_gptest = data[['drive-wheels','body-style','price']]
grouped_test2=df_gptest[['drive-wheels', 'price']].groupby(['drive-wheels'])
grouped_test2.head()
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 2            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 6            fwd  17710.0
# 7            fwd  18920.0
# 8            fwd  23875.0
# 9            rwd  16430.0
# 10           rwd  16925.0
# 136          4wd   7603.0
# 140          4wd   9233.0
# 141          4wd  11259.0
# 144          4wd   8013.0

# %%
grouped_test2.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %%
#Anova
f_value,p_value= stats.f_oneway(grouped_test2.get_group('fwd')['price'],grouped_test2.get_group('rwd')['price'],grouped_test2.get_group('4wd')['price'])
print( "ANOVA results: F=", f_value, ", P =", p_value) 

#Generally used for the categorical data
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %% [markdown]
# This is a great result, with a large F test score showing a strong correlation

# %%
f_val, p_val = stats.f_oneway(grouped_test2.get_group('fwd')['price'], grouped_test2.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %%
df3=data[['make','price']]
grp3=df3[['make','price']].groupby(['make'])
grp3

# %%
print('For AUDI : ')
grp3.get_group('audi')['price']
#grp3.get_group('bmw')['price']
# Out:
# For AUDI :
# 3    13950.0
# 4    17450.0
# 5    15250.0
# 6    17710.0
# 7    18920.0
# 8    23875.0
# Name: price, dtype: float64

# %%
f_val, p_val = stats.f_oneway(grp3.get_group('audi')['price'],grp3.get_group('bmw')['price'],grp3.get_group('chevrolet')['price'],grp3.get_group('jaguar')['price'])
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 11.799571346177299 , P = 0.00025029425006206906

# %% [markdown]
# SO here F-test score too much small,Hence there is weak correlation.
