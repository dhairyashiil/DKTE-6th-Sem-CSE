# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.relplot(x="passengers",y="month",data=flights, hue="year")

# %%
sns.relplot(x="passengers",y="month",data=flights,hue="year" ,kind="line")

# %%
sns.catplot(x="month",y="year",data=flights)

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill", y="tip",data=tips, hue="smoker")

# %%
sns.relplot(x="total_bill", y="tip",data=tips, hue="sex")

# %%
sns.relplot(x="total_bill", y="tip",data=tips, hue="smoker" , style="smoker")

# %%
sns.relplot(x="total_bill", y="tip",data=tips, hue="smoker" , style="time")

# %%
sns.relplot(x="total_bill", y="tip",data=tips , style="time")

# %%
sns.relplot(x="total_bill", y="tip",data=tips, hue="size")

# %%
sns.catplot(x="day", y="tip",data=tips)

# %% [markdown]
# Jitter Attribute

# %%
sns.catplot(x="day", y="total_bill",data=tips, jitter=False)

# %%
sns.catplot(x="day", y="tip", data=tips ,kind="swarm")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="total_bill", y="day", data=tips, hue="time")

# %%
sns.catplot(x="total_bill", y="day", data=tips, hue="size")

# %%
sns.catplot(x="total_bill", y="day", data=tips, hue="smoker")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="box")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", palette="ch:.5")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", palette="ch:.5", hue="smoker")

# %%
sns.catplot(x="day", y="total_bill", data=tips, kind="bar", palette="pastel", hue="smoker")

# %%
sns.catplot(x="day", y="total_bill", hue="smoker", kind="box", data=tips)

# %%
sns.stripplot(x="day", y="total_bill", data=tips,hue="smoker")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="total_bill", y="day", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
diamonds=sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(x="color", y="price", data=diamonds)

# %%
sns.catplot(x="color", y="price", data=diamonds.sort_values("color"), kind="boxen")

# %%
sns.relplot(x="carat",y="price", data=diamonds, hue="color", style="color",)

# %%
sns.catplot(x="clarity", y="price", data=diamonds)

# %%
sns.catplot(x="clarity", y="price", data=diamonds)
fig ,ax =plt.subplots()
sns.lineplot(x="carat", y="price", data=diamonds, hue="color")
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.barplot(x="color", y="price",data=diamonds)
# Out:
# <AxesSubplot:xlabel='color', ylabel='price'>

# %%
df=diamonds['color'].values[0]
df
# Out:
# 'E'

# %% [markdown]
# sns.lineplot(x="carat", y="price", data=diamonds, hue=df)

# %%
titanic= sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
plt.grid()

# %%
sns.catplot(x="deck", kind="count", palette="ch:2.5", data=titanic)
sns.catplot(x="deck", kind="count", palette="ch:0.5", data=titanic)

# %%
sns.catplot(y="deck", hue="class", kind="count",palette="pastel", edgecolor=".6",data=titanic)
